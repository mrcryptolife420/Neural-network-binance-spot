# %% [markdown]
# # Scanner

# %%
payload = {
  "created_at_ms": 1778847724651,
  "rows": [
    {
      "symbol": "BTCUSDT",
      "spread_bps": 1.0,
      "volume": 100.0,
      "signal": "BUY",
      "confidence": 0.8,
      "score": 0.79901
    }
  ],
  "orders_allowed": false
}
payload
